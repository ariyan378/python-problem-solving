# %% [markdown]
# #Dictionary

# %%
d1 = {
    'Name' :"Ariyan Islam hridoy",
    'Id':378,
    'Section' : 'J',
    'Batch' : 65
}
print(d1)
# Out:
# {'Name': 'Ariyan Islam hridoy', 'Id': 378, 'Section': 'J', 'Batch': 65}

# %%
d1 = {
    'Name' :"Ariyan Islam hridoy",
    'Id':378,
    'Section' : 'J',
    'Batch' : 65,
    'Subject' : {
        'Microprocessor' : 90,
        'Compiler Design' : 60,
        'Accounting':70,
        'Statistics':55  
    }
}
print(d1)
# Out:
# {'Name': 'Ariyan Islam hridoy', 'Id': 378, 'Section': 'J', 'Batch': 65, 'Subject': {'Microprocessor': 90, 'Compiler Design': 60, 'Accounting': 70, 'Statistics': 55}}

# %%
d2 = dict([('name', 'himu'),('age', 23)])
print(d2)
# Out:
# {'name': 'himu', 'age': 23}

# %%
d1['Subject']['Compiler Design']=65

# %%
d1['Subject']['Microprocessor']
# Out:
# 90

# %%
print(d1)
# Out:
# {'Name': 'Ariyan Islam hridoy', 'Id': 378, 'Section': 'J', 'Batch': 65, 'Subject': {'Microprocessor': 90, 'Compiler Design': 65, 'Accounting': 70}}

# %%
del d1['Subject']['Statistics']

# %%
print(d1)
# Out:
# {'Name': 'Ariyan Islam hridoy', 'Id': 378, 'Section': 'J', 'Batch': 65, 'Subject': {'Microprocessor': 90, 'Compiler Design': 60, 'Accounting': 70}}

# %%
for i in d1:
    print(i ,d1[i])
# Out:
# Name Ariyan Islam hridoy
# Id 378
# Section J
# Batch 65
# Subject {'Microprocessor': 90, 'Compiler Design': 60, 'Accounting': 70}

# %%
len(d1)
# Out:
# 5

# %%
d1.items()
# Out:
# dict_items([('Name', 'Ariyan Islam hridoy'), ('Id', 378), ('Section', 'J'), ('Batch', 65), ('Subject', {'Microprocessor': 90, 'Compiler Design': 60, 'Accounting': 70})])

# %%
d1.keys()
# Out:
# dict_keys(['Name', 'Id', 'Section', 'Batch', 'Subject'])

# %%
d1.values()
# Out:
# dict_values(['Ariyan Islam hridoy', 378, 'J', 65, {'Microprocessor': 90, 'Compiler Design': 60, 'Accounting': 70}])

# %%
# using zip
days = ["Sunday", "Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"]
temp_C = [30.5,32.6,31.8,33.4,29.8,30.2,29.9]

for (key,value) in zip(days,temp_C):
    print(f"{key}:{value}")
# Out:
# Sunday:30.5
# Monday:32.6
# Tuesday:31.8
# Wednesday:33.4
# Thursday:29.8
# Friday:30.2
# Saturday:29.9

# %%
# using if condition
products = {'phone':10,'laptop':0,'charger':32,'tablet':0}

for (i , j) in products.items():
    print(f"{i}:{j}")
# Out:
# phone:10
# laptop:0
# charger:32
# tablet:0
