# %%
import numpy as np

# %%
a1 = np.arange(10,dtype=int)
a2 = np.arange(12).reshape(3,4)
a3 = np.arange(8).reshape(2,2,2)

# %%
a1.ndim
a2.ndim
# Out:
# 2

# %%
print(a3.shape)
# Out:
# (2, 2, 2)

# %%
a3.itemsize
# Out:
# 8

# %%
a3.astype(np.int32)
# Out:
# array([[[0, 1],
#         [2, 3]],
#
#        [[4, 5],
#         [6, 7]]], dtype=int32)
