# %% [markdown]
# # 🔢 NumPy Problem Solving for Data Analysts
# ### 20 Real-Life Practice Questions | Easy → Hard
#
# ---
# > **How to use this notebook:** Each cell contains one problem. Read the scenario, then write your NumPy solution in the empty code cell below it. Try to solve each one before looking anything up!
#
# **Topics covered:** Array creation, indexing, math operations, statistics, filtering, broadcasting, reshaping, and more.
#
# ---

# %% [markdown]
# ## 🟢 EASY (Problems 1–6)
# *Core skills: Array creation, basic operations, simple statistics*

# %% [markdown]
# ### Problem 1 — Store Daily Sales
#
# A small grocery store recorded its **daily sales (in USD)** for one week:
#
# | Mon | Tue | Wed | Thu | Fri | Sat | Sun |
# |-----|-----|-----|-----|-----|-----|-----|
# | 320 | 450 | 380 | 290 | 510 | 620 | 480 |
#
# **Tasks:**
# 1. Store this data in a NumPy array.
# 2. Find the **total**, **average**, **highest**, and **lowest** sales of the week.
# 3. On how many days did sales **exceed $400**?

# %%
import numpy as np

# Your solution here

# %% [markdown]
# ---
# ### Problem 2 — Student Test Scores
#
# A teacher has test scores (out of 100) for **30 students**. Instead of typing them manually, she wants to **simulate** the scores for practice.
#
# **Tasks:**
# 1. Generate an array of **30 random integer scores between 40 and 100** (use `np.random.randint`).
# 2. Find how many students **passed** (score ≥ 50).
# 3. Find how many students scored in the **top grade** (score ≥ 80).
# 4. What is the **class average**? Round it to 2 decimal places.

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 3 — Temperature Conversion
#
# A weather station recorded the **temperature in Celsius** for 10 days in a city:
#
# `[22, 19, 35, 28, 31, 17, 40, 26, 23, 30]`
#
# The international report requires temperatures in **Fahrenheit**. Formula: `F = (C × 9/5) + 32`
#
# **Tasks:**
# 1. Convert all temperatures to Fahrenheit **without using a loop**.
# 2. Find the **hottest** and **coldest** day (in both Celsius and Fahrenheit).
# 3. How many days were **above 30°C**?

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 4 — Product Price Discount
#
# An e-commerce site has **8 products** with original prices (in USD):
#
# `[120, 85, 200, 55, 340, 99, 150, 60]`
#
# The site is running a **20% discount** on all products.
#
# **Tasks:**
# 1. Calculate the **discounted price** for every product.
# 2. Calculate the **amount saved** on each product.
# 3. Which products have a discounted price **below $80**?
# 4. What is the **total revenue** if all products are sold at the discounted price?

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 5 — Hospital Patient Ages
#
# A hospital recorded the **ages of 12 patients** admitted on one day:
#
# `[34, 67, 23, 45, 78, 56, 12, 89, 43, 61, 29, 52]`
#
# **Tasks:**
# 1. Find the **median age** and **mean age** of the patients.
# 2. Classify patients into two groups using boolean indexing:
#    - **Senior** (age ≥ 60)
#    - **Non-Senior** (age < 60)
# 3. How many patients fall in each group?
# 4. Sort the ages in **ascending order** and display the result.

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 6 — Counting Unique Website Visitors
#
# A website tracks which **hour of the day** (0–23) each visitor arrives. Here is one day's log of 20 visits:
#
# `[3, 14, 9, 22, 14, 7, 14, 3, 19, 9, 22, 14, 7, 3, 14, 9, 19, 22, 7, 14]`
#
# **Tasks:**
# 1. Find the **unique hours** when visitors arrived.
# 2. Find which hour had the **most visits** (peak hour).
# 3. Use `np.unique()` with `return_counts=True` to count visits per unique hour.
# 4. How many visits happened **between 6 AM and 12 PM** (hours 6–11)?

# %%
# Your solution here

# %% [markdown]
# ---
# ## 🟡 MEDIUM (Problems 7–13)
# *Core skills: 2D arrays, reshaping, aggregation, broadcasting, statistics*

# %% [markdown]
# ### Problem 7 — Monthly Sales Grid
#
# A company has **4 sales regions** and tracks revenue for **3 months** (Jan, Feb, Mar). The data is:
#
# ```
#           Jan    Feb    Mar
# North  [ 5000,  4800,  5200 ]
# South  [ 3200,  3500,  3100 ]
# East   [ 4100,  3900,  4400 ]
# West   [ 6200,  5800,  6100 ]
# ```
#
# **Tasks:**
# 1. Store this as a **2D NumPy array** of shape (4, 3).
# 2. Find the **total revenue per region** (sum across months).
# 3. Find the **average revenue per month** (average across all regions).
# 4. Which region had the **highest total revenue** over 3 months?
# 5. Which month had the **highest total revenue** across all regions?

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 8 — Sensor Data Cleaning
#
# A factory sensor records **temperature every hour** for 24 hours. Due to sensor errors, some readings are invalid and stored as **-999**:
#
# `[72, 75, -999, 78, 80, 79, -999, 76, 74, 73, 77, 81, 82, 80, 79, -999, 75, 74, 76, 78, 80, 83, 81, 79]`
#
# **Tasks:**
# 1. Replace all **-999 values with `np.nan`**.
# 2. Calculate the **mean temperature** ignoring the invalid readings (use `np.nanmean`).
# 3. How many **valid readings** were there?
# 4. Replace the `nan` values with the **mean temperature** (imputation).
# 5. Verify that the cleaned array has **no more nan values**.

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 9 — Exam Score Normalization
#
# A data science bootcamp has **50 students**. After the final exam, the instructor wants to **normalize** scores so they fall between 0 and 1, making it easy to compare across different exams.
#
# **Tasks:**
# 1. Simulate **50 exam scores** between 30 and 100 using `np.random.randint` (set seed to 42).
# 2. Apply **Min-Max Normalization**: `normalized = (x - min) / (max - min)`.
# 3. Apply **Z-score Standardization**: `z = (x - mean) / std`.
# 4. Verify that the normalized scores are **all between 0 and 1**.
# 5. What is the **mean and standard deviation** of the Z-score array? (Should be ~0 and ~1)

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 10 — Sales Commission Calculator
#
# A company pays its **5 salespeople** different commission rates. Here is their monthly sales and commission rates:
#
# ```
# Sales (USD): [15000, 22000, 18500, 9800, 31000]
# Commission %: [5, 7, 6, 4, 8]
# ```
#
# **Tasks:**
# 1. Calculate each salesperson's **commission earned** using element-wise multiplication (no loop).
# 2. If the company sets a **bonus rule**: anyone who earns more than $1,500 in commission gets an extra flat $500 bonus — apply this using NumPy boolean indexing.
# 3. Calculate each person's **total payout** (commission + bonus).
# 4. What is the **total commission cost** to the company?

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 11 — Reshaping Survey Data
#
# A survey was conducted with **12 participants**. Each person answered **5 questions**, rated from 1 to 5. The raw results came in as one flat list of 60 values.
#
# **Tasks:**
# 1. Generate a **flat array of 60 random integers** between 1 and 5 (use seed=10).
# 2. **Reshape** it into a (12, 5) matrix where rows = participants, columns = questions.
# 3. Calculate the **average score per question** (column-wise).
# 4. Calculate the **total score per participant** (row-wise).
# 5. Find the **participant with the highest total score**. Return their row index.

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 12 — Stock Price Moving Average
#
# An investor tracks a stock's **daily closing price** for 15 trading days:
#
# `[102, 105, 103, 108, 110, 107, 112, 115, 113, 116, 119, 118, 121, 124, 122]`
#
# A **3-day moving average** smooths out short-term fluctuations.
#
# **Tasks:**
# 1. Calculate the **3-day moving average** manually using NumPy slicing and `np.convolve` or a loop-free approach.
# 2. Find the **daily price change** (difference between each day and the previous day).
# 3. On how many days did the price **go up** vs **go down**?
# 4. What was the **largest single-day gain** and **largest single-day loss**?

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 13 — Broadcasting: Budget vs Actual Spending
#
# A company tracks **monthly budget vs actual spending** for **4 departments** over **6 months**.
#
# ```python
# # Monthly budget for each department (fixed every month)
# budget = np.array([10000, 8000, 12000, 9500])  # shape (4,)
#
# # Actual spending — shape (6, 4) → 6 months, 4 departments
# actual = np.array([
#     [9800,  8200, 11500, 9000],
#     [10200, 7900, 12400, 9800],
#     [9500,  8100, 11800, 9300],
#     [10500, 8300, 12100, 9700],
#     [9900,  7800, 11600, 9100],
#     [10100, 8050, 12300, 9600]
# ])
# ```
#
# **Tasks:**
# 1. Use **broadcasting** to calculate the **variance from budget** (actual − budget) for every month and department.
# 2. Find months where **any department exceeded its budget**.
# 3. Find which **department overspent the most in total** across 6 months.
# 4. Calculate each department's **average monthly spending** as a percentage of its budget.

# %%
# Your solution here

# %% [markdown]
# ---
# ## 🔴 HARD (Problems 14–20)
# *Core skills: Advanced statistics, linear algebra, simulation, multi-dimensional analysis*

# %% [markdown]
# ### Problem 14 — Correlation Between Advertising & Sales
#
# A marketing team wants to understand if **ad spend drives sales**. They have data for 12 months:
#
# ```python
# ad_spend  = np.array([200, 250, 180, 300, 350, 400, 420, 390, 310, 270, 230, 200])
# sales     = np.array([820, 910, 780, 1050, 1200, 1350, 1400, 1280, 1050, 950, 870, 810])
# ```
#
# **Tasks:**
# 1. Calculate the **Pearson correlation coefficient** between ad spend and sales using only NumPy (no pandas/scipy).
# 2. Use `np.polyfit(ad_spend, sales, 1)` to find the **best-fit linear regression line** (slope and intercept).
# 3. Using the regression line, **predict sales** if ad spend is $500.
# 4. Calculate the **residuals** (actual − predicted) for each month.
# 5. What is the **Root Mean Square Error (RMSE)** of your regression model?

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 15 — Customer Purchase Percentile Ranking
#
# An e-commerce platform has **1,000 customers**. The analytics team wants to rank customers by how much they spend so they can target the **top spenders** with loyalty rewards.
#
# **Tasks:**
# 1. Simulate **1,000 customer purchase amounts** using `np.random.normal(mean=250, std=80)` (set seed=7). Round to 2 decimals and clip all values to be ≥ 0.
# 2. Calculate the **25th, 50th, 75th, and 95th percentile** spending values.
# 3. Identify customers in the **top 5%** (above 95th percentile). How many are there?
# 4. Calculate the **Interquartile Range (IQR)**. Flag any customers whose spending is **outside 1.5×IQR** from Q1/Q3 as outliers.
# 5. How many **outlier customers** are there, and what is their average spending?

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 16 — Image Brightness Analysis (Grayscale)
#
# In data science, images are just 2D arrays of pixel values (0 = black, 255 = white). A small **8×8 grayscale image** is represented below.
#
# **Tasks:**
# 1. Create a random **8×8 array with integer values between 0 and 255** (seed=3). This is your "image."
# 2. Find the **mean brightness**, **darkest pixel**, and **brightest pixel**.
# 3. Apply a **threshold**: set all pixels with brightness < 128 to 0 (dark), and all ≥ 128 to 255 (bright). This is binary thresholding.
# 4. After thresholding, what **percentage of pixels are bright** (value = 255)?
# 5. Flip the image **horizontally** using NumPy (left becomes right). What NumPy function achieves this?

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 17 — Monte Carlo Simulation: Risk Analysis
#
# A project manager estimates a project will take between **20 and 50 days** to complete. Using a Monte Carlo simulation, we can estimate the **probability of finishing within 35 days**.
#
# **Tasks:**
# 1. Simulate **100,000 project durations** drawn from a **uniform distribution** between 20 and 50 days (use `np.random.uniform`, seed=0).
# 2. What is the **probability** (as a %) that the project finishes in **35 days or less**?
# 3. What is the **minimum duration** to guarantee a **90% chance** of completion? (Use `np.percentile`)
# 4. Calculate the **mean** and **standard deviation** of estimated project durations.
# 5. What percentage of simulations fell within **one standard deviation** of the mean?

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 18 — Multi-Store Inventory Analysis
#
# A retail chain has **5 stores** and tracks **8 products**. The inventory count for each store-product combination is stored in a 5×8 matrix.
#
# **Tasks:**
# 1. Generate a **5×8 random integer array** with values between 0 and 100 (seed=99). This represents stock levels.
# 2. Find all **store-product combinations where stock is below 20** (low stock alert). Return the indices.
# 3. For each store (row), compute the **total inventory value** assuming each product has a price: `prices = [10, 25, 15, 40, 8, 30, 20, 12]`.
# 4. Use broadcasting to compute the **inventory value matrix** (stock × price) without a loop.
# 5. Which **store** has the **highest total inventory value**? Which **product** is the most stocked across all stores?

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 19 — Cohort Retention Analysis
#
# A mobile app tracks how many users from an initial cohort of **1,000** are still active after each week. The retention data for **4 cohorts** over **8 weeks** (as percentages) is:
#
# ```python
# retention = np.array([
#     [100, 65, 48, 35, 28, 22, 18, 15],  # Cohort Jan
#     [100, 70, 52, 40, 31, 25, 20, 17],  # Cohort Feb
#     [100, 60, 44, 32, 24, 19, 15, 12],  # Cohort Mar
#     [100, 75, 58, 45, 36, 29, 24, 20],  # Cohort Apr
# ])
# ```
#
# **Tasks:**
# 1. Calculate the **week-over-week drop in retention** for each cohort (use `np.diff`).
# 2. Which **week had the steepest average drop** across all cohorts?
# 3. Which **cohort retained users the best** at Week 8? (Highest Week 8 value)
# 4. Calculate the **average retention curve** across all 4 cohorts (column-wise mean).
# 5. If each active user generates **$2/week** in revenue, calculate the **total revenue per cohort** over 8 weeks (assume 1,000 users to start).

# %%
# Your solution here

# %% [markdown]
# ---
# ### Problem 20 — A/B Test Analysis from Scratch
#
# A product team runs an **A/B test** on two versions of a checkout button (A = blue, B = green). They record conversion rates (1 = converted, 0 = not converted) for 500 users in each group.
#
# **Tasks:**
# 1. Simulate Group A with a **40% conversion rate** and Group B with a **45% conversion rate** using `np.random.binomial(1, p, 500)`. Set seed=21.
# 2. Calculate the **conversion rate** for each group.
# 3. Calculate the **absolute lift** (difference in conversion rates) and **relative lift** (lift / control rate × 100%).
# 4. Use a **bootstrap resampling** approach (1,000 iterations) to estimate the **95% confidence interval** for the difference in conversion rates:
#    - Each iteration: randomly sample (with replacement) 500 from A and 500 from B, compute difference.
#    - Use `np.percentile` on the 1,000 differences to get the 2.5th and 97.5th percentile.
# 5. Based on the confidence interval, does it **exclude 0**? What does that tell the product team about the test result?

# %%
# Your solution here

# %% [markdown]
# ---
#
# ## 🏁 You Made It!
#
# | Level | Problems | Skills Practiced |
# |-------|----------|------------------|
# | 🟢 Easy | 1–6 | Array creation, filtering, basic stats, sorting |
# | 🟡 Medium | 7–13 | 2D arrays, cleaning, normalization, broadcasting |
# | 🔴 Hard | 14–20 | Regression, simulation, linear algebra, A/B testing |
#
# ### 💡 Tips to go further:
# - Try solving each problem **multiple ways** (loops vs vectorized)
# - Once comfortable, connect these NumPy skills to **Pandas** and **Matplotlib**
# - Re-do the Hard problems without looking at the problem scaffold — just the scenario
#
# ---
# *Built for aspiring data analysts — from grocery stores to A/B tests, NumPy is everywhere.*
