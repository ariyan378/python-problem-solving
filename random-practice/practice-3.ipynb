# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Set style
plt.style.use('seaborn-v0_8')  # or 'default', 'ggplot', etc.
sns.set_style("whitegrid")

# %%
x = np.linspace(0,10,100)
y = np.sin(x)

plt.figure(figsize=(10,6))
plt.plot(x,y)
plt.title("Simple sin wave", fontdict={"fontsize": 18,
        "color": "Black",
        "fontweight": "bold" })
plt.xlabel("X-Axis")
plt.ylabel('Y-Axis')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6), dpi=300)

x = np.linspace(0,10,100)
y = np.sin(x)
y2=np.cos(x)
y3=np.tan(x)

plt.plot(x,y,label='Sin')
plt.plot(x,y2,label='Cos')
plt.plot(x,y3, label='Tan')

plt.title('Simple Multiline Plot', fontdict={
    'fontsize':18,
    'color':'Black',
    'fontweight':'bold'
})

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid(True)
plt.legend()
plt.show()
